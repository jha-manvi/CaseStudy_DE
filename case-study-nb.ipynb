# %%
import pandas as pd
from datetime import date

# %%
#Loading Oct'20 dataset
df_oct_prod = pd.read_csv('src_data/20201001220037_products.csv',sep=';');

# %%
df_oct_price = pd.read_csv('src_data/20201001220039_prices.csv',sep=';');

# %%
df_oct_cntr = pd.read_csv('src_data/20201001220144_contracts.csv',sep=';')

# %%
#Loading Nov'20 datasets
df_nov_prod = pd.read_csv('src_data/20201101220035_products.csv',sep=';');
df_nov_price = pd.read_csv('src_data/20201101220039_prices.csv',sep=';');
df_nov_cntr = pd.read_csv('src_data/20201101230133_contracts.csv',sep=';');

# %%
#Loading Dec'20 datasets
df_dec_prod = pd.read_csv('src_data/20201201220034_products.csv',sep=';');
df_dec_price = pd.read_csv('src_data/20201201220101_prices.csv',sep=';');
df_dec_cntr = pd.read_csv('src_data/20201201220059_contracts.csv',sep=';');

# %%
#Loading Jan'21 datasets
df_jan_prod = pd.read_csv('src_data/20210101220045_products.csv',sep=';');
df_jan_price = pd.read_csv('src_data/20210101220057_prices.csv',sep=';');
df_jan_cntr = pd.read_csv('src_data/20210101220104_contracts.csv',sep=';');

# %%
df_cont=df_oct_cntr.append(df_nov_cntr,ignore_index=True).append(df_dec_cntr,ignore_index=True).append(df_jan_cntr,ignore_index=True)

# %%
df_cont.drop_duplicates().
# Out:
#            id    type       energy   usage  usagenet   createdat   startdate  \
# 0           1  energy  electricity  2100.0    2084.0  2018-03-12  2018-12-01
# 1           2  energy  electricity  2700.0    2569.0  2018-01-26  2018-10-01
# 2           3  energy  electricity  2900.0    2760.0  2019-04-09  2019-09-01
# 3           4  energy  electricity  2500.0    2391.0  2019-09-27  2019-11-01
# 4           5  energy  electricity  2200.0    2178.0  2020-04-01  2020-11-01
# ...       ...     ...          ...     ...       ...         ...         ...
# 131595  36096  energy  electricity  2500.0    2457.0  2020-12-14  2021-06-01
# 131596  36097  energy  electricity  3000.0    2891.0  2020-12-29  2021-01-01
# 131597  36098  energy  electricity  2400.0    2281.0  2020-12-05  2021-06-01
# 131598  36099  energy  electricity  2600.0    2535.0  2020-12-28  2021-02-01
# 131599  36100  energy  electricity  3000.0    2816.0  2020-12-30  2021-02-01
#
# ...

# %%
df_oct_price
# Out:
#     id  productid  pricecomponentid productcomponent  price    unit  \
# 0    1       1000                 1        baseprice   8.99  €/year
# 1    2       1000                 2     workingprice  29.80  ct/kwh
# 2    3       1001                 1        baseprice   9.99  €/year
# 3    4       1002                 1        baseprice   9.49  €/year
# 4    5       1001                 2     workingprice  29.40  ct/kwh
# 5    6       1002                 2     workingprice  28.90  ct/kwh
# 6    7       2001                 1        baseprice  13.99  €/year
# 7    8       2001                 2     workingprice   4.90  ct/kwh
# 8    9       2002                 1        baseprice  13.99  €/year
# 9   10       2002                 2     workingprice   5.20  ct/kwh
# 10  11       1002                 2     workingprice  29.10  €/year
# 11  12       1001                 2     workingprice  29.30  ct/kwh
# 12  13       1000                 1        baseprice   9.79  €/year
# ...

# %%
df_oct_cntr
# Out:
#           id    type       energy  usage  usagenet   createdat   startdate  \
# 0          1  energy  electricity   2100    2084.0  2018-03-12  2018-12-01
# 1          2  energy  electricity   2700    2569.0  2018-01-26  2018-10-01
# 2          3  energy  electricity   2900    2760.0  2019-04-09  2019-09-01
# 3          4  energy  electricity   2500    2391.0  2019-09-27  2019-11-01
# 4          5  energy  electricity   2200    2178.0  2020-04-01  2020-11-01
# ...      ...     ...          ...    ...       ...         ...         ...
# 29995  29996  energy          gas   9500    9246.0  2020-03-21  2020-06-01
# 29996  29997  energy  electricity   2700    2866.0  2019-12-23  2020-07-01
# 29997  29998  energy  electricity   2800    2932.0  2018-02-19  2018-08-01
# 29998  29999  energy  electricity   2300    2383.0  2019-08-01  2019-10-01
# 29999  30000  energy  electricity   2500    2429.0  2019-11-06  2020-02-01
#
# ...

# %%
df_nov_cntr
# Out:
#           id    type       energy    usage  usagenet   createdat   startdate  \
# 0          1  energy  electricity   2100.0    2084.0  2018-03-12  2018-12-01
# 1          2  energy  electricity   2700.0    2569.0  2018-01-26  2018-10-01
# 2          3  energy  electricity   2900.0    2760.0  2019-04-09  2019-09-01
# 3          4  energy  electricity   2500.0    2391.0  2019-09-27  2019-11-01
# 4          5  energy  electricity   2200.0    2178.0  2020-04-01  2020-11-01
# ...      ...     ...          ...      ...       ...         ...         ...
# 31795  31796  energy  electricity   2300.0    2257.0  2020-10-18  2020-12-01
# 31796  31797  energy          gas  10500.0   10356.0  2020-10-15  2020-12-01
# 31797  31798  energy  electricity   2800.0    2796.0  2020-10-26  2020-12-01
# 31798  31799  energy  electricity   2400.0    2407.0  2020-10-12  2020-11-01
# 31799  31800  energy          gas   8700.0    8922.0  2020-10-25  2022-03-01
#
# ...

# %%
df_nov_prod
# Out:
#      id productcode productname       energy        consumptiontype  deleted  \
# 0  1000      energy  ÖkoStrom A  electricity  household_electricity        0
# 1  1001      energy  ÖkoStrom B  electricity  household_electricity        0
# 2  1002      energy  ÖkoStrom C  electricity  household_electricity        0
# 3  2001      energy    ÖkoGas A          gas              universal        0
# 4  2002      energy    ÖkoGas B          gas              universal        0
# 5  9001      energy   ÖkoTest A  electricity  household_electricity        0
#
#   modificationdate
# 0       2020-08-27
# 1       2020-02-05
# 2       2020-01-01
# 3       2019-05-21
# 4       2020-06-04
# 5       2020-11-29

# %%
df_nov_price
# Out:
#     id  productid  pricecomponentid productcomponent  price    unit  \
# 0    1       1000                 1        baseprice   8.99  €/year
# 1    2       1000                 2     workingprice  29.80  ct/kwh
# 2    3       1001                 1        baseprice   9.99  €/year
# 3    4       1002                 1        baseprice   9.49  €/year
# 4    5       1001                 2     workingprice  29.40  ct/kwh
# 5    6       1002                 2     workingprice  28.90  ct/kwh
# 6    7       2001                 1        baseprice  13.99  €/year
# 7    8       2001                 2     workingprice   4.90  ct/kwh
# 8    9       2002                 1        baseprice  13.99  €/year
# 9   10       2002                 2     workingprice   5.20  ct/kwh
# 10  11       1002                 2     workingprice  29.10  €/year
# 11  12       1001                 2     workingprice  29.30  ct/kwh
# 12  13       1000                 1        baseprice   9.79  €/year
# ...

# %%
df_oct_prod.shape
# Out:
# (5, 7)

# %%
df_nov_prod.shape
# Out:
# (6, 7)

# %%
df_dec_prod.shape
# Out:
# (6, 7)

# %%
df_jan_prod.shape
# Out:
# (6, 7)

# %%
df_oct_price.shape
# Out:
# (14, 9)

# %%
df_nov_price.shape
# Out:
# (14, 9)

# %%
df_dec_price.shape
# Out:
# (14, 9)

# %%
df_jan_price.shape
# Out:
# (18, 9)

# %%
df_oct_cntr
# Out:
#           id    type       energy  usage  usagenet   createdat   startdate  \
# 0          1  energy  electricity   2100    2084.0  2018-03-12  2018-12-01
# 1          2  energy  electricity   2700    2569.0  2018-01-26  2018-10-01
# 2          3  energy  electricity   2900    2760.0  2019-04-09  2019-09-01
# 3          4  energy  electricity   2500    2391.0  2019-09-27  2019-11-01
# 4          5  energy  electricity   2200    2178.0  2020-04-01  2020-11-01
# ...      ...     ...          ...    ...       ...         ...         ...
# 29995  29996  energy          gas   9500    9246.0  2020-03-21  2020-06-01
# 29996  29997  energy  electricity   2700    2866.0  2019-12-23  2020-07-01
# 29997  29998  energy  electricity   2800    2932.0  2018-02-19  2018-08-01
# 29998  29999  energy  electricity   2300    2383.0  2019-08-01  2019-10-01
# 29999  30000  energy  electricity   2500    2429.0  2019-11-06  2020-02-01
#
# ...

# %%
df_oct_cntr.shape
# Out:
# (30000, 14)

# %%
df_nov_cntr.shape
# Out:
# (31800, 14)

# %%
df_dec_cntr.shape
# Out:
# (33700, 14)

# %%
df_jan_cntr.shape
# Out:
# (36100, 14)

# %%
df_oct_prod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                5 non-null      int64
#  1   productcode       5 non-null      object
#  2   productname       5 non-null      object
#  3   energy            5 non-null      object
#  4   consumptiontype   5 non-null      object
#  5   deleted           5 non-null      int64
#  6   modificationdate  5 non-null      object
# dtypes: int64(2), object(5)
# memory usage: 408.0+ bytes

# %%
df_oct_prod.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df_nov_prod.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
df_dec_prod.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
df_jan_prod.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
df_jan_price.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# dtype: bool

# %%
df_oct_prod.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df_nov_price.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# dtype: bool

# %%
df_dec_price.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# dtype: bool

# %%
df_oct_cntr.duplicated().unique()
# Out:
# array([False])

# %%
df_nov_cntr.duplicated().unique()
# Out:
# array([False])

# %%
df_dec_cntr.duplicated().unique()
# Out:
# array([False])

# %%
df_jan_cntr.duplicated().unique()
# Out:
# array([False])

# %%
df_jan_cntr
# Out:
#           id    type       energy   usage  usagenet   createdat   startdate  \
# 0          1  energy  electricity  2100.0    2084.0  2018-03-12  2018-12-01
# 1          2  energy  electricity  2700.0    2569.0  2018-01-26  2018-10-01
# 2          3  energy  electricity  2900.0    2760.0  2019-04-09  2019-09-01
# 3          4  energy  electricity  2500.0    2391.0  2019-09-27  2019-11-01
# 4          5  energy  electricity  2200.0    2178.0  2020-04-01  2020-11-01
# ...      ...     ...          ...     ...       ...         ...         ...
# 36095  36096  energy  electricity  2500.0    2457.0  2020-12-14  2021-06-01
# 36096  36097  energy  electricity  3000.0    2891.0  2020-12-29  2021-01-01
# 36097  36098  energy  electricity  2400.0    2281.0  2020-12-05  2021-06-01
# 36098  36099  energy  electricity  2600.0    2535.0  2020-12-28  2021-02-01
# 36099  36100  energy  electricity  3000.0    2816.0  2020-12-30  2021-02-01
#
# ...

# %%
df_jan_cntr['status'].unique()
# Out:
# array(['indelivery', 'terminated', 'active', 'cancelled'], dtype=object)

# %%
df_jan_cntr[df_jan_cntr['startdate'] == '2021-01-01']
# Out:
#           id    type       energy    usage  usagenet   createdat   startdate  \
# 315      316  energy          gas  11700.0   12086.0  2020-09-21  2021-01-01
# 394      395  energy  electricity   2600.0    2560.0  2020-09-24  2021-01-01
# 434      435  energy          gas  10700.0   10354.0  2020-05-11  2021-01-01
# 496      497  energy  electricity   2900.0    2737.0  2020-07-14  2021-01-01
# 546      547  energy  electricity   1900.0    2015.0  2020-09-28  2021-01-01
# ...      ...     ...          ...      ...       ...         ...         ...
# 36074  36075  energy  electricity   2800.0    2843.0  2020-12-09  2021-01-01
# 36083  36084  energy  electricity   2200.0    2208.0  2020-12-01  2021-01-01
# 36084  36085  energy          gas   8200.0    8557.0  2020-12-16  2021-01-01
# 36092  36093  energy  electricity   2800.0    2884.0  2020-12-02  2021-01-01
# 36096  36097  energy  electricity   3000.0    2891.0  2020-12-29  2021-01-01
#
# ...

# %%
len(df_jan_cntr[df_jan_cntr['startdate'] == '2021-01-01']['id'].unique().tolist())
# Out:
# 1296

# %%
today = date.today()
print("Today's date:", today)
# Out:
# Today's date: 2022-04-03

# %%
year = year.today()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8784f88c83b6> in <module>
# ----> 1 year = year.today()
#
# NameError: name 'year' is not defined

# %%
print(today.month)
# Out:
# 4

# %%
print(today.year)
# Out:
# 2022

# %%
print(str(today.day).zfill(2))
# Out:
# 03

# %%
table_nm = ['prices','products','contracts']

# %%
for i in range(0,len(table_nm)):
    print(table_nm[i])
# Out:
# prices
# products
# contracts

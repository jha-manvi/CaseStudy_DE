# %%
import pandas as pd;

# %%
df_cont=pd.read_csv("/Users/manvijha/Documents/MyProjects/CaseStudy_DE/output_files/op_contracts.csv",sep=",")

# %%
df1=df_cont[df_cont['status']=='indelivery']

# %%
df1
# Out:
#           id    type       energy  usage  usagenet   createdat   startdate  \
# 0          1  energy  electricity   2100    2084.0  2018-03-12  2018-12-01
# 1          2  energy  electricity   2700    2569.0  2018-01-26  2018-10-01
# 2          3  energy  electricity   2900    2760.0  2019-04-09  2019-09-01
# 5          6  energy  electricity   2400    2375.0  2020-02-02  2020-07-01
# 6          7  energy  electricity   2800    2915.0  2019-07-20  2019-09-01
# ...      ...     ...          ...    ...       ...         ...         ...
# 30793  30785  energy  electricity   2700    2624.0  2020-10-01  2020-10-01
# 30947  30939  energy  electricity   2200    2094.0  2020-10-01  2020-10-01
# 31177  31169  energy  electricity   2300    2370.0  2020-10-01  2020-10-01
# 31529  31524  energy  electricity   2500    2633.0  2020-10-01  2020-10-01
# 31575  31570  energy  electricity   2400    2301.0  2020-10-01  2020-10-01
#
# ...

# %%
df1[df1['startdate']=='2021-01-01']
# Out:
# Empty DataFrame
# Columns: [id, type, energy, usage, usagenet, createdat, startdate, enddate, fillingdatecancellation, cancellationreason, city, status, productid, modificationdate]
# Index: []

# %%
df1[df1['startdate']>'2021-01-01']
# Out:
# Empty DataFrame
# Columns: [id, type, energy, usage, usagenet, createdat, startdate, enddate, fillingdatecancellation, cancellationreason, city, status, productid, modificationdate]
# Index: []

# %%
df1[df1['startdate']=='2021-01-01']
